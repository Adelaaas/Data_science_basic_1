# %%
def a(b):
  c=[b*4,b*b,(2*b**2)**0.5]
  return c
b=int(input())
p=a(b)
p
# Out:
# 2
# [8, 4, 2.8284271247461903]

# %%
a=list(map(int,input().split()))
b=list(map(int,input().split()))
g=list()
for i in a:
  if b.count(i)==0:
    g.append(i)
for i in b:
  if a.count(i)==0:
    g.append(i)
g
# Out:
# 1 2 3
# 4 5 6
# [1, 2, 3, 4, 5, 6]

# %%
import numpy as np

f=list(map(int,input().split()))
x=np.array(f)
j=-1
h=-1000000000000000000000000000000000000
for i in range(1,len(f)):
  if(x[i-1]==0 and x[i]!=0 and j==-1):
    h=x[i]
    j=0
  elif(x[i]>h and x[i-1]==0 and x[i]!=0):
    h=x[i]
if(h==-1000000000000000000000000000000000000):
  print("___")
else:
  print(h)
# Out:
# 1 2 3 4
# ___

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("titanic.csv")
print(df['Age'].mean())
print(df['Fare'].max())

x = ['1', '0']
y = [len(df[df['Survived']==1]), len(df[df['Survived']==0])]
fig, ax = plt.subplots()
ax.bar(x, y)
fig.set_facecolor('floralwhite')
plt.show()

print(df.isna().sum())
df.dropna(axis=0, how='any')
# Out:
# 29.69911764705882
# 512.3292
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#      PassengerId  Survived  Pclass  ...     Fare        Cabin  Embarked
# 1              2         1       1  ...  71.2833          C85         C
# 3              4         1       1  ...  53.1000         C123         S
# 6              7         0       1  ...  51.8625          E46         S
# 10            11         1       3  ...  16.7000           G6         S
# 11            12         1       1  ...  26.5500         C103         S
# ..           ...       ...     ...  ...      ...          ...       ...
# 871          872         1       1  ...  52.5542          D35         S
# 872          873         0       1  ...   5.0000  B51 B53 B55         S
# 879          880         1       1  ...  83.1583          C50         C
# 887          888         1       1  ...  30.0000          B42         S
# 889          890         1       1  ...  30.0000         C148         C
#
# [183 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
