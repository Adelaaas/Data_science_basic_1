# %%
#Hw2

#1
import numpy as np
from numpy import ndarray

a = np.zeros((10, 10), int)
a[0::9, ::] = a[::, 0::9] = 1
print(a)

#2
import numpy as np
from numpy import ndarray

a: ndarray = np.diag(range(1, 5), b=1)
print(a)

#3
import numpy as np
from numpy import ndarray

x = np.random.rand(5, 10)
y = [x[i] - x[i].mean() for i in range(x.shape[0])]
print(y)

#4
import numpy as np
from numpy import ndarray

a = np.random.rand(6, 7)
print(f"\n{a}")
a[2::3, ::] = a[5::-3, ::]
print(f"\n{a}")


#5
import numpy as np
from numpy import ndarray

a= []
for i in range(4):
    a.append([])
    for j in range(6):
        a[i].append(np.random.randint(1, 9))
b = np.array(np.int32(a), int)
print(b)


#6
import numpy as np
from numpy import ndarray

a = 0
b = np.random.randint(-50, 50, size=(89, 67))
for i in range(89):
    for j in range(67):
        if b[i][j] != 0:
            a += 1
print(a)


#7
import numpy as np
from numpy import ndarray

a, b = map(int, input().split())
c = np.zeros((a, b))
for i in range(a):
    for j in range(m):
        if (i + j) % 2 != 0:
            c[i, j] = 1
print(c)

#8
import numpy as np
from numpy import ndarray
from math import ceil
from math import floor

a = np.array([float(i) for i in input().split()])
b = []
for j in range(len(a)):
    if a[j] < 0:
        b.append(floor(a[j]))
    else:
        b.append(ceil(a[j]))
print(b)

#9
import numpy as np
from numpy import ndarray

a = np.array(np.random.rand(10) * 10, int)
b = np.array(np.random.rand(10) * 10, int)
c = []
print(f'{a}\n{b}')
for i in range(10):
    if any(a[i] == b):
        c.append(a[i])
print(sorted(set(c)))
# Out:
# ПривЕТ МИр!
