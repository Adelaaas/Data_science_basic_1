# %%
import pandas as pd
df = pd.read_csv('data.csv')
df = df.drop('Loaned From', 1)
df=df.dropna()
df
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 4               4  192985  ...       13.0         €196.4M
# 5               5  183277  ...        8.0         €172.1M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [14743 rows x 88 columns]

# %%
df["res"]=None
df.shape
# Out:
# (14743, 89)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14743 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                14743 non-null  int64
#  1   ID                        14743 non-null  int64
#  2   Name                      14743 non-null  object
#  3   Age                       14743 non-null  int64
#  4   Photo                     14743 non-null  object
#  5   Nationality               14743 non-null  object
#  6   Flag                      14743 non-null  object
#  7   Overall                   14743 non-null  int64
#  8   Potential                 14743 non-null  int64
#  9   Club                      14743 non-null  object
#  10  Club Logo                 14743 non-null  object
#  11  Value                     14743 non-null  object
#  12  Wage                      14743 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# ID                0
# Name              0
# Age               0
# Photo             0
#                  ..
# GKHandling        0
# GKKicking         0
# GKPositioning     0
# GKReflexes        0
# Release Clause    0
# Length: 88, dtype: int64

# %%
X = df.loc[:,['Agility','Reactions']]
Y = df['res']

# %%
SSE = [] 
for k in range(1,30):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(X)
    SSE.append(kmeans.inertia_)
plt.plot(range(1,30), SSE, marker='s');
plt.xlabel('k')
plt.ylabel('SSE');
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Agility'],df['Reactions'])
plt.xlabel('Agility')
plt.ylabel('Reactions')
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=28)
kmeans.fit(X)
Y = kmeans.labels_
Y
# Out:
# array([14, 14, 14, ..., 11,  7,  4], dtype=int32)

# %%
X['cluster'] = Y
X
# Out:
#        Agility  Reactions  cluster
# 0         91.0       95.0        2
# 1         87.0       96.0        2
# 2         96.0       94.0        2
# 4         79.0       91.0        2
# 5         95.0       90.0        2
# ...        ...        ...      ...
# 18202     60.0       49.0        1
# 18203     38.0       40.0        0
# 18204     50.0       47.0        0
# 18205     52.0       21.0        1
# 18206     55.0       51.0        0
#
# [14743 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(X[X['cluster']==0]['Agility'], X[X['cluster']==0]['Reactions'], 'bo', label='class1')
plt.plot(X[X['cluster']==1]['Agility'], X[X['cluster']==1]['Reactions'], 'go', label='class2')
plt.plot(X[X['cluster']==2]['Agility'], X[X['cluster']==2]['Reactions'], 'ro', label='class3')
plt.plot(X[X['cluster']==2]['Agility'], X[X['cluster']==2]['Reactions'], 'ro', label='class3')
plt.xlabel('Agility')
plt.ylabel('Reactions')
plt.legend(loc=0)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df1 = pd.read_csv('data.csv')
df1 = df1.drop('Loaned From', 1)
df1=df1.dropna()
df1["res"]=None
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Unnamed: 0      ID                Name  ...  GKReflexes Release Clause   res
# 0               0  158023            L. Messi  ...         8.0        €226.5M  None
# 1               1   20801   Cristiano Ronaldo  ...        11.0        €127.1M  None
# 2               2  190871           Neymar Jr  ...        11.0        €228.1M  None
# 4               4  192985        K. De Bruyne  ...        13.0        €196.4M  None
# 5               5  183277           E. Hazard  ...         8.0        €172.1M  None
# ...           ...     ...                 ...  ...         ...            ...   ...
# ...

# %%
X1 = df1.loc[:,['Agility','Reactions']]
X1
# Out:
#        Agility  Reactions
# 0         91.0       95.0
# 1         87.0       96.0
# 2         96.0       94.0
# 4         79.0       91.0
# 5         95.0       90.0
# ...        ...        ...
# 18202     60.0       49.0
# 18203     38.0       40.0
# 18204     50.0       47.0
# 18205     52.0       21.0
# 18206     55.0       51.0
#
# [14743 rows x 2 columns]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
Z = linkage(X, 'ward')
fig = plt.figure(figsize=(10, 10))
dn = dendrogram(Z)

# %%
from scipy.cluster.hierarchy import linkage
Z = linkage(X, method='average', metric='euclidean')
Z[0]
# Out:
# array([13., 46.,  0.,  2.])

# %%
from scipy.cluster.hierarchy import fcluster
label = fcluster(Z, 10, criterion='distance')
np.unique(label)
label
# Out:
# array([27, 27, 27, ..., 11,  7, 10], dtype=int32)

# %%
df1["res"]=label
df1
# Out:
#        Unnamed: 0      ID                Name  ...  GKReflexes Release Clause res
# 0               0  158023            L. Messi  ...         8.0        €226.5M  27
# 1               1   20801   Cristiano Ronaldo  ...        11.0        €127.1M  27
# 2               2  190871           Neymar Jr  ...        11.0        €228.1M  27
# 4               4  192985        K. De Bruyne  ...        13.0        €196.4M  26
# 5               5  183277           E. Hazard  ...         8.0        €172.1M  28
# ...           ...     ...                 ...  ...         ...            ...  ..
# 18202       18202  238813        J. Lundstram  ...         9.0          €143K  10
# 18203       18203  243165  N. Christoffersson  ...        12.0          €113K  11
# 18204       18204  241638           B. Worman  ...        13.0          €165K  11
# 18205       18205  246268      D. Walker-Rice  ...         9.0          €143K   7
# ...

# %%
from matplotlib import pyplot as plt
plt.scatter(df.loc[label==1, 'Agility'], df.loc[label==1, 'Reactions'], s=50, marker='o', color='red')
plt.scatter(df.loc[label==2, 'Agility'], df.loc[label==2, 'Reactions'], s=50, marker='o', color='blue')
plt.scatter(df.loc[label==3, 'Agility'], df.loc[label==3, 'Reactions'], s=50, marker='o', color='green')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)
y_hc
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
X['pred'] = y_hc
X
# Out:
#        Agility  Reactions  cluster  pred_sklearn  pred
# 0         91.0       95.0        2             1     1
# 1         87.0       96.0        2             1     1
# 2         96.0       94.0        2             1     1
# 4         79.0       91.0        2             2     2
# 5         95.0       90.0        2             1     1
# ...        ...        ...      ...           ...   ...
# 18202     60.0       49.0        1             0     0
# 18203     38.0       40.0        0             0     0
# 18204     50.0       47.0        0             0     0
# 18205     52.0       21.0        1             0     0
# 18206     55.0       51.0        0             0     0
#
# [14743 rows x 5 columns]

# %%
plt.scatter(X.loc[y_hc==0, 'Agility'], X.loc[y_hc==0, 'Reactions'], s=50, marker='o', color='red')
plt.scatter(X.loc[y_hc==1, 'Agility'], X.loc[y_hc==1, 'Reactions'], s=50, marker='o', color='blue')
plt.scatter(X.loc[y_hc==2, 'Agility'], X.loc[y_hc==2, 'Reactions'], s=50, marker='o', color='green')
plt.show()
